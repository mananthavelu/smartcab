# %%
import random
import math
from environment import Agent, Environment
from planner import RoutePlanner
from simulator import Simulator
random.seed(10)
class LearningAgent(Agent):
    """ An agent that learns to drive in the Smartcab world.
        This is the object you will be modifying. """

    def __init__(self, env, learning=False, epsilon=1.0, alpha=0.5):
        super(LearningAgent, self).__init__(env)     # Set the agent in the evironment
        self.planner = RoutePlanner(self.env, self)  # Create a route planner
        self.valid_actions = self.env.valid_actions  # The set of valid actions

        # Set parameters of the learning agent
        self.learning = learning # Whether the agent is expected to learn
        self.Q = dict()          # Create a Q-table which will be a dictionary of tuples
        self.epsilon = epsilon   # Random exploration factor
        self.alpha = alpha       # Learning factor

        ###########
        ## TO DO ##
        ###########
        # Set any additional class parameters as needed
        self.trial=0

    def reset(self, destination=None, testing=False):
        """ The reset function is called at the beginning of each trial.
            'testing' is set to True if testing trials are being used
            once training trials have completed. """

        # Select the destination as the new location to route to
        self.planner.route_to(destination)

        ###########
        ## TO DO ##
        ###########
        # Update epsilon using a decay function of your choice
        # Update additional class parameters as needed
        # If 'testing' is True, set epsilon and alpha to 0
        if testing==True:
            self.epsilon=0
            self.alpha=0
        else:
            self.trial+=1
            self.epsilon = math.pow(0.99,self.trial)
        return None

    def build_state(self):
        """ The build_state function is called when the agent requests data from the
            environment. The next waypoint, the intersection inputs, and the deadline
            are all features available to the agent. """

        # Collect data about the environment
        waypoint = self.planner.next_waypoint() # The next waypoint
        inputs = self.env.sense(self)           # Visual input - intersection light and traffic
        deadline = self.env.get_deadline(self)  # Remaining deadline

        ###########
        ## TO DO ##
        ###########
        # Set 'state' as a tuple of relevant data for the agent
        state = (inputs['light'], inputs['oncoming'], inputs['left'], waypoint)

        return state


    def get_maxQ(self, state):
        """ The get_max_Q function is called when the agent is asked to find the
            maximum Q-value of all actions based on the 'state' the smartcab is in. """

        ###########
        ## TO DO ##
        ###########
        # Calculate the maximum Q-value of all actions for a given state
        maxQ = max(self.Q[state].values())
        return maxQ


    def createQ(self, state):
        """ The createQ function is called when a state is generated by the agent. """

        ###########
        ## TO DO ##
        ###########
        # When learning, check if the 'state' is not in the Q-table
        # If it is not, create a new dictionary for that state
        #   Then, for each action available, set the initial Q-value to 0.0
        if self.learning==True:
            if state not in self.Q.keys():
                self.Q[state]=dict()
                self.Q[state][None] = 0.0
                self.Q[state]['forward'] = 0.0
                self.Q[state]['left'] = 0.0
                self.Q[state]['right'] = 0.0
        return


    def choose_action(self, state):
        """ The choose_action function is called when the agent is asked to choose
            which action to take, based on the 'state' the smartcab is in. """

        # Set the agent state and default action
        self.state = state
        self.next_waypoint = self.planner.next_waypoint()
        action = None

        ###########
        ## TO DO ##
        ###########
        # When not learning, choose a random action
        # When learning, choose a random action with 'epsilon' probability
        #   Otherwise, choose an action with the highest Q-value for the current state
        constraint = random.randrange(0, 10)
        if self.learning==True:
            if constraint< self.epsilon:
                action = random.choice(self.env.valid_actions)
            else:
                maxQ = self.get_maxQ(state)
                possible_action=[]
                for key in self.Q[state].keys():
                    if self.Q[state][key] == maxQ:
                        possible_action.append(key)
                action=random.choice(possible_action)
        else:
            action = random.choice(self.env.valid_actions)
        return action


    def learn(self, state, action, reward):
        """ The learn function is called after the agent completes an action and
            receives an award. This function does not consider future rewards
            when conducting learning. """

        ###########
        ## TO DO ##
        ###########
        # When learning, implement the value iteration update rule
        #   Use only the learning rate 'alpha' (do not use the discount factor 'gamma')
        if self.learning==True:
            q_old = self.Q[state][action]
            self.Q[self.state][action] = (1 - self.alpha) * q_old + (self.alpha * reward)
        return


    def update(self):
        """ The update function is called when a time step is completed in the
            environment for a given trial. This function will build the agent
            state, choose an action, receive a reward, and learn if enabled. """

        state = self.build_state()          # Get current state
        self.createQ(state)                 # Create 'state' in Q-table
        action = self.choose_action(state)  # Choose an action
        reward = self.env.act(self, action) # Receive a reward
        self.learn(state, action, reward)   # Q-learn

        return


def run():
    """ Driving function for running the simulation.
        Press ESC to close the simulation, or [SPACE] to pause the simulation. """

    ##############
    # Create the environment
    # Flags:
    #   verbose     - set to True to display additional output from the simulation
    #   num_dummies - discrete number of dummy agents in the environment, default is 100
    #   grid_size   - discrete number of intersections (columns, rows), default is (8, 6)
    env = Environment(verbose=True)

    ##############
    # Create the driving agent
    # Flags:
    #   learning   - set to True to force the driving agent to use Q-learning
    #    * epsilon - continuous value for the exploration factor, default is 1
    #    * alpha   - continuous value for the learning rate, default is 0.5
    agent = env.create_agent(LearningAgent, learning=True,epsilon=1.0,alpha=0.8)

    ##############
    # Follow the driving agent
    # Flags:
    #   enforce_deadline - set to True to enforce a deadline metric
    env.set_primary_agent(agent, enforce_deadline=True)

    ##############
    # Create the simulation
    # Flags:
    #   update_delay - continuous time (in seconds) between actions, default is 2.0 seconds
    #   display      - set to False to disable the GUI if PyGame is enabled
    #   log_metrics  - set to True to log trial and simulation results to /logs
    #   optimized    - set to True to change the default log file name
    sim = Simulator(env,update_delay=0.01, log_metrics=True,optimized=True)

    ##############
    # Run the simulator
    # Flags:
    #   tolerance  - epsilon tolerance before beginning testing, default is 0.05
    #   n_test     - discrete number of testing trials to perform, default is 0
    sim.run(n_test=10)


if __name__ == '__main__':
    run()
# Out:
# /-------------------------
# | Training trial 1
# \-------------------------
#
# Environment.reset(): Trial set up with start = (3, 7), destination = (6, 4), deadline = 30
# Simulating trial. . .
# epsilon = 0.9900; alpha = 0.8000
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# Environment.step(): t = 0
# Environment.act() [POST]: location: (3, 7), heading: (1, 0), action: left, reward: -39.512028323
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'right', 'right': 'left', 'left': 'forward'}, 'violation': 4, 'light': 'red', 'state': ('red', 'right', 'forward', 'forward'), 'deadline': 30, 't': 0, 'action': 'left', 'reward': -39.512028322972284, 'waypoint': 'forward'}
# Agent previous state: ('red', 'right', 'forward', 'forward')
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.51)
# 97% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# Environment.step(): t = 1
# Environment.act() [POST]: location: (3, 7), heading: (1, 0), action: forward, reward: -9.29083594297
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': 'right', 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'forward', None, 'forward'), 'deadline': 29, 't': 1, 'action': 'forward', 'reward': -9.290835942965533, 'waypoint': 'forward'}
# Agent previous state: ('red', 'forward', None, 'forward')
# Agent attempted driving forward through a red light. (rewarded -9.29)
# 93% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# Environment.step(): t = 2
# Environment.act() [POST]: location: (3, 7), heading: (1, 0), action: None, reward: 2.05282607042
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'forward', None, 'forward'), 'deadline': 28, 't': 2, 'action': None, 'reward': 2.052826070421548, 'waypoint': 'forward'}
# Agent previous state: ('red', 'forward', None, 'forward')
# Agent properly idled at a red light. (rewarded 2.05)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# Environment.step(): t = 3
# Environment.act() [POST]: location: (3, 7), heading: (1, 0), action: None, reward: 2.63859084877
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'forward', None, 'forward'), 'deadline': 27, 't': 3, 'action': None, 'reward': 2.6385908487664795, 'waypoint': 'forward'}
# Agent previous state: ('red', 'forward', None, 'forward')
# Agent properly idled at a red light. (rewarded 2.64)
# 87% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# Environment.step(): t = 4
# Environment.act() [POST]: location: (3, 7), heading: (1, 0), action: None, reward: 2.81121520109
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': 'forward', 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'forward', None, 'forward'), 'deadline': 26, 't': 4, 'action': None, 'reward': 2.8112152010859655, 'waypoint': 'forward'}
# Agent previous state: ('red', 'forward', None, 'forward')
# Agent properly idled at a red light. (rewarded 2.81)
# 83% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# Environment.step(): t = 5
# Environment.act() [POST]: location: (3, 7), heading: (1, 0), action: None, reward: -5.28845636557
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'forward', 'right': 'right', 'left': None}, 'violation': 1, 'light': 'green', 'state': ('green', 'forward', None, 'forward'), 'deadline': 25, 't': 5, 'action': None, 'reward': -5.288456365571292, 'waypoint': 'forward'}
# Agent previous state: ('green', 'forward', None, 'forward')
# Agent idled at a green light with no oncoming traffic. (rewarded -5.29)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# Environment.step(): t = 6
# Environment.act() [POST]: location: (3, 6), heading: (0, -1), action: left, reward: 1.57726264062
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': 'right', 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'forward'), 'deadline': 24, 't': 6, 'action': 'left', 'reward': 1.5772626406174366, 'waypoint': 'forward'}
# Agent previous state: ('green', None, None, 'forward')
# Agent drove left instead of forward. (rewarded 1.58)
# 77% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# Environment.step(): t = 7
# Environment.act() [POST]: location: (4, 6), heading: (1, 0), action: right, reward: 1.08629277573
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': 'left', 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', None, None, 'right'), 'deadline': 23, 't': 7, 'action': 'right', 'reward': 1.0862927757289724, 'waypoint': 'right'}
# Agent previous state: ('red', None, None, 'right')
# Agent followed the waypoint right. (rewarded 1.09)
# 73% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# Environment.step(): t = 8
# Environment.act() [POST]: location: (4, 7), heading: (0, 1), action: right, reward: 1.79871394685
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': 'left', 'left': 'right'}, 'violation': 0, 'light': 'green', 'state': ('green', None, 'right', 'forward'), 'deadline': 22, 't': 8, 'action': 'right', 'reward': 1.7987139468512545, 'waypoint': 'forward'}
# Agent previous state: ('green', None, 'right', 'forward')
# Agent drove right instead of forward. (rewarded 1.80)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# Environment.step(): t = 9
# Environment.act() [POST]: location: (4, 7), heading: (0, 1), action: forward, reward: -10.793510784
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'left'}, 'violation': 2, 'light': 'red', 'state': ('red', None, 'left', 'left'), 'deadline': 21, 't': 9, 'action': 'forward', 'reward': -10.793510783955016, 'waypoint': 'left'}
# Agent previous state: ('red', None, 'left', 'left')
# Agent attempted driving forward through a red light. (rewarded -10.79)
# 67% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# Environment.step(): t = 10
# Environment.act() [POST]: location: (4, 7), heading: (0, 1), action: left, reward: -10.9540514396
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': 'right', 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', None, None, 'left'), 'deadline': 20, 't': 10, 'action': 'left', 'reward': -10.954051439619908, 'waypoint': 'left'}
# Agent previous state: ('red', None, None, 'left')
# Agent attempted driving left through a red light. (rewarded -10.95)
# 63% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# Environment.step(): t = 11
# Environment.act() [POST]: location: (4, 7), heading: (0, 1), action: forward, reward: -40.0685950227
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'}, 'violation': 4, 'light': 'red', 'state': ('red', None, 'forward', 'left'), 'deadline': 19, 't': 11, 'action': 'forward', 'reward': -40.06859502269284, 'waypoint': 'left'}
# Agent previous state: ('red', None, 'forward', 'left')
# Agent attempted driving forward through a red light with traffic and cause a major accident. (rewarded -40.07)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# Environment.step(): t = 12
# Environment.act() [POST]: location: (4, 7), heading: (0, 1), action: None, reward: 2.32738902197
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': 'forward'}, 'violation': 0, 'light': 'red', 'state': ('red', None, 'forward', 'left'), 'deadline': 18, 't': 12, 'action': None, 'reward': 2.327389021968492, 'waypoint': 'left'}
# Agent previous state: ('red', None, 'forward', 'left')
# Agent properly idled at a red light. (rewarded 2.33)
# 57% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# Environment.step(): t = 13
# Environment.act() [POST]: location: (3, 7), heading: (-1, 0), action: right, reward: 0.0719558108832
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'left'), 'deadline': 17, 't': 13, 'action': 'right', 'reward': 0.07195581088317948, 'waypoint': 'left'}
# Agent previous state: ('green', None, None, 'left')
# Agent drove right instead of left. (rewarded 0.07)
# 53% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# Environment.step(): t = 14
# Environment.act() [POST]: location: (3, 2), heading: (0, 1), action: left, reward: 0.808906668343
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'}, 'violation': 0, 'light': 'green', 'state': ('green', None, 'forward', 'left'), 'deadline': 16, 't': 14, 'action': 'left', 'reward': 0.8089066683431696, 'waypoint': 'left'}
# Agent previous state: ('green', None, 'forward', 'left')
# Agent followed the waypoint left. (rewarded 0.81)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# Environment.step(): t = 15
# Environment.act() [POST]: location: (3, 2), heading: (0, 1), action: left, reward: -40.5481810631
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'right', 'right': 'left', 'left': None}, 'violation': 4, 'light': 'red', 'state': ('red', 'right', None, 'left'), 'deadline': 15, 't': 15, 'action': 'left', 'reward': -40.54818106314136, 'waypoint': 'left'}
# Agent previous state: ('red', 'right', None, 'left')
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -40.55)
# 47% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# Environment.step(): t = 16
# Environment.act() [POST]: location: (2, 2), heading: (-1, 0), action: right, reward: 1.02878944569
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'left'), 'deadline': 14, 't': 16, 'action': 'right', 'reward': 1.0287894456873556, 'waypoint': 'left'}
# Agent previous state: ('green', None, None, 'left')
# Agent drove right instead of left. (rewarded 1.03)
# 43% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# Environment.step(): t = 17
# Environment.act() [POST]: location: (2, 7), heading: (0, -1), action: right, reward: 1.02548684202
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': 'right'}, 'violation': 0, 'light': 'green', 'state': ('green', None, 'right', 'forward'), 'deadline': 13, 't': 17, 'action': 'right', 'reward': 1.0254868420218595, 'waypoint': 'forward'}
# Agent previous state: ('green', None, 'right', 'forward')
# Agent drove right instead of forward. (rewarded 1.03)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# Environment.step(): t = 18
# Environment.act() [POST]: location: (2, 7), heading: (0, -1), action: left, reward: -9.63320517286
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'forward', None, 'left'), 'deadline': 12, 't': 18, 'action': 'left', 'reward': -9.633205172860265, 'waypoint': 'left'}
# Agent previous state: ('red', 'forward', None, 'left')
# Agent attempted driving left through a red light. (rewarded -9.63)
# 37% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# Environment.step(): t = 19
# Environment.act() [POST]: location: (2, 7), heading: (0, -1), action: forward, reward: -10.9676943574
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'forward', None, 'left'), 'deadline': 11, 't': 19, 'action': 'forward', 'reward': -10.967694357376738, 'waypoint': 'left'}
# Agent previous state: ('red', 'forward', None, 'left')
# Agent attempted driving forward through a red light. (rewarded -10.97)
# 33% of time remaining to reach destination.
#
# /-------------------
# | Step 20 Results
# \-------------------
#
# Environment.step(): t = 20
# Environment.act() [POST]: location: (3, 7), heading: (1, 0), action: right, reward: 0.277630462213
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'forward', None, 'left'), 'deadline': 10, 't': 20, 'action': 'right', 'reward': 0.2776304622130583, 'waypoint': 'left'}
# Agent previous state: ('red', 'forward', None, 'left')
# Agent drove right instead of left. (rewarded 0.28)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 21 Results
# \-------------------
#
# Environment.step(): t = 21
# Environment.act() [POST]: location: (3, 2), heading: (0, 1), action: right, reward: 0.898685070574
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', None, 'forward'), 'deadline': 9, 't': 21, 'action': 'right', 'reward': 0.8986850705741635, 'waypoint': 'forward'}
# Agent previous state: ('green', 'left', None, 'forward')
# Agent drove right instead of forward. (rewarded 0.90)
# 27% of time remaining to reach destination.
#
# /-------------------
# | Step 22 Results
# \-------------------
#
# Environment.step(): t = 22
# Environment.act() [POST]: location: (2, 2), heading: (-1, 0), action: right, reward: 0.607356337525
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 8, 't': 22, 'action': 'right', 'reward': 0.6073563375251247, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent drove right instead of left. (rewarded 0.61)
# 23% of time remaining to reach destination.
#
# /-------------------
# | Step 23 Results
# \-------------------
#
# Environment.step(): t = 23
# Environment.act() [POST]: location: (2, 2), heading: (-1, 0), action: forward, reward: -10.0516489621
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'left'}, 'violation': 2, 'light': 'red', 'state': ('red', None, 'left', 'forward'), 'deadline': 7, 't': 23, 'action': 'forward', 'reward': -10.051648962058353, 'waypoint': 'forward'}
# Agent previous state: ('red', None, 'left', 'forward')
# Agent attempted driving forward through a red light. (rewarded -10.05)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 24 Results
# \-------------------
#
# Environment.step(): t = 24
# Environment.act() [POST]: location: (2, 7), heading: (0, -1), action: right, reward: 0.697288593203
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', None, None, 'forward'), 'deadline': 6, 't': 24, 'action': 'right', 'reward': 0.6972885932033499, 'waypoint': 'forward'}
# Agent previous state: ('red', None, None, 'forward')
# Agent drove right instead of forward. (rewarded 0.70)
# 17% of time remaining to reach destination.
#
# /-------------------
# | Step 25 Results
# \-------------------
#
# Environment.step(): t = 25
# Environment.act() [POST]: location: (3, 7), heading: (1, 0), action: right, reward: 0.568031840061
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'left'), 'deadline': 5, 't': 25, 'action': 'right', 'reward': 0.568031840061052, 'waypoint': 'left'}
# Agent previous state: ('green', None, None, 'left')
# Agent drove right instead of left. (rewarded 0.57)
# 13% of time remaining to reach destination.
#
# /-------------------
# | Step 26 Results
# \-------------------
#
# Environment.step(): t = 26
# Environment.act() [POST]: location: (3, 2), heading: (0, 1), action: right, reward: 0.17591125081
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', None, None, 'forward'), 'deadline': 4, 't': 26, 'action': 'right', 'reward': 0.1759112508101972, 'waypoint': 'forward'}
# Agent previous state: ('red', None, None, 'forward')
# Agent drove right instead of forward. (rewarded 0.18)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 27 Results
# \-------------------
#
# Environment.step(): t = 27
# Environment.act() [POST]: location: (2, 2), heading: (-1, 0), action: right, reward: 0.903537758134
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': None, 'left': 'forward'}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', 'forward', 'left'), 'deadline': 3, 't': 27, 'action': 'right', 'reward': 0.9035377581335797, 'waypoint': 'left'}
# Agent previous state: ('green', 'left', 'forward', 'left')
# Agent drove right instead of left. (rewarded 0.90)
# 7% of time remaining to reach destination.
#
# /-------------------
# | Step 28 Results
# \-------------------
#
# Environment.step(): t = 28
# Environment.act() [POST]: location: (2, 2), heading: (-1, 0), action: None, reward: 1.40865727225
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'forward', None, 'forward'), 'deadline': 2, 't': 28, 'action': None, 'reward': 1.408657272250699, 'waypoint': 'forward'}
# Agent previous state: ('red', 'forward', None, 'forward')
# Agent properly idled at a red light. (rewarded 1.41)
# 3% of time remaining to reach destination.
#
# /-------------------
# | Step 29 Results
# \-------------------
#
# Environment.step(): t = 29
# Environment.act() [POST]: location: (2, 2), heading: (-1, 0), action: left, reward: -19.3064526051
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'forward', 'right': 'forward', 'left': None}, 'violation': 3, 'light': 'green', 'state': ('green', 'forward', None, 'forward'), 'deadline': 1, 't': 29, 'action': 'left', 'reward': -19.306452605141413, 'waypoint': 'forward'}
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Agent previous state: ('green', 'forward', None, 'forward')
# Agent attempted driving left through traffic and cause a minor accident. (rewarded -19.31)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 2
# \-------------------------
#
# Environment.reset(): Trial set up with start = (5, 7), destination = (1, 2), deadline = 25
# Simulating trial. . .
# epsilon = 0.9801; alpha = 0.8000
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# Environment.step(): t = 0
# Environment.act() [POST]: location: (6, 7), heading: (1, 0), action: right, reward: 1.77158649325
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': 'left', 'left': 'right'}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', 'right', 'right'), 'deadline': 25, 't': 0, 'action': 'right', 'reward': 1.7715864932497674, 'waypoint': 'right'}
# Agent previous state: ('green', 'left', 'right', 'right')
# Agent followed the waypoint right. (rewarded 1.77)
# 96% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# Environment.step(): t = 1
# Environment.act() [POST]: location: (6, 7), heading: (1, 0), action: forward, reward: -10.7301935454
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'left', None, 'forward'), 'deadline': 24, 't': 1, 'action': 'forward', 'reward': -10.73019354536613, 'waypoint': 'forward'}
# Agent previous state: ('red', 'left', None, 'forward')
# Agent attempted driving forward through a red light. (rewarded -10.73)
# 92% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# Environment.step(): t = 2
# Environment.act() [POST]: location: (6, 7), heading: (1, 0), action: left, reward: -10.744295418
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'left', None, 'forward'), 'deadline': 23, 't': 2, 'action': 'left', 'reward': -10.744295417987315, 'waypoint': 'forward'}
# Agent previous state: ('red', 'left', None, 'forward')
# Agent attempted driving left through a red light. (rewarded -10.74)
# 88% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# Environment.step(): t = 3
# Environment.act() [POST]: location: (6, 7), heading: (1, 0), action: None, reward: 1.33096004879
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'forward'}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', 'forward', 'forward'), 'deadline': 22, 't': 3, 'action': None, 'reward': 1.3309600487890645, 'waypoint': 'forward'}
# Agent previous state: ('red', 'left', 'forward', 'forward')
# Agent properly idled at a red light. (rewarded 1.33)
# 84% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# Environment.step(): t = 4
# Environment.act() [POST]: location: (7, 7), heading: (1, 0), action: forward, reward: 1.67011415078
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': None, 'left': 'left'}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', 'left', 'forward'), 'deadline': 21, 't': 4, 'action': 'forward', 'reward': 1.6701141507830053, 'waypoint': 'forward'}
# Agent previous state: ('green', 'left', 'left', 'forward')
# Agent followed the waypoint forward. (rewarded 1.67)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# Environment.step(): t = 5
# Environment.act() [POST]: location: (7, 2), heading: (0, 1), action: right, reward: 0.6171018166
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': 'forward', 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', None, 'forward'), 'deadline': 20, 't': 5, 'action': 'right', 'reward': 0.6171018166001493, 'waypoint': 'forward'}
# Agent previous state: ('green', 'left', None, 'forward')
# Agent drove right instead of forward. (rewarded 0.62)
# 76% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# Environment.step(): t = 6
# Environment.act() [POST]: location: (6, 2), heading: (-1, 0), action: right, reward: 0.537514064169
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': 'left', 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'left'), 'deadline': 19, 't': 6, 'action': 'right', 'reward': 0.5375140641693287, 'waypoint': 'left'}
# Agent previous state: ('green', None, None, 'left')
# Agent drove right instead of left. (rewarded 0.54)
# 72% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# Environment.step(): t = 7
# Environment.act() [POST]: location: (6, 7), heading: (0, -1), action: right, reward: 1.94677344463
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'right'), 'deadline': 18, 't': 7, 'action': 'right', 'reward': 1.946773444628874, 'waypoint': 'right'}
# Agent previous state: ('green', None, None, 'right')
# Agent followed the waypoint right. (rewarded 1.95)
# 68% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# Environment.step(): t = 8
# Environment.act() [POST]: location: (6, 6), heading: (0, -1), action: forward, reward: 1.05178680582
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': 'right'}, 'violation': 0, 'light': 'green', 'state': ('green', None, 'right', 'right'), 'deadline': 17, 't': 8, 'action': 'forward', 'reward': 1.051786805819939, 'waypoint': 'right'}
# Agent previous state: ('green', None, 'right', 'right')
# Agent drove forward instead of right. (rewarded 1.05)
# 64% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# Environment.step(): t = 9
# Environment.act() [POST]: location: (6, 6), heading: (0, -1), action: left, reward: -9.35830048157
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'forward', None, 'right'), 'deadline': 16, 't': 9, 'action': 'left', 'reward': -9.35830048156821, 'waypoint': 'right'}
# Agent previous state: ('red', 'forward', None, 'right')
# Agent attempted driving left through a red light. (rewarded -9.36)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# Environment.step(): t = 10
# Environment.act() [POST]: location: (6, 6), heading: (0, -1), action: forward, reward: -9.72529922965
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'forward', None, 'right'), 'deadline': 15, 't': 10, 'action': 'forward', 'reward': -9.72529922965341, 'waypoint': 'right'}
# Agent previous state: ('red', 'forward', None, 'right')
# Agent attempted driving forward through a red light. (rewarded -9.73)
# 56% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# Environment.step(): t = 11
# Environment.act() [POST]: location: (6, 6), heading: (0, -1), action: left, reward: -19.7306361085
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'forward', 'right': 'left', 'left': None}, 'violation': 3, 'light': 'green', 'state': ('green', 'forward', None, 'right'), 'deadline': 14, 't': 11, 'action': 'left', 'reward': -19.730636108493222, 'waypoint': 'right'}
# Agent previous state: ('green', 'forward', None, 'right')
# Agent attempted driving left through traffic and cause a minor accident. (rewarded -19.73)
# 52% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# Environment.step(): t = 12
# Environment.act() [POST]: location: (6, 6), heading: (0, -1), action: None, reward: -4.59438654164
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': 'left', 'left': 'left'}, 'violation': 1, 'light': 'green', 'state': ('green', None, 'left', 'right'), 'deadline': 13, 't': 12, 'action': None, 'reward': -4.594386541636828, 'waypoint': 'right'}
# Agent previous state: ('green', None, 'left', 'right')
# Agent idled at a green light with no oncoming traffic. (rewarded -4.59)
# 48% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# Environment.step(): t = 13
# Environment.act() [POST]: location: (6, 6), heading: (0, -1), action: left, reward: -20.0429578857
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'right', 'right': 'left', 'left': 'left'}, 'violation': 3, 'light': 'green', 'state': ('green', 'right', 'left', 'right'), 'deadline': 12, 't': 13, 'action': 'left', 'reward': -20.042957885670468, 'waypoint': 'right'}
# Agent previous state: ('green', 'right', 'left', 'right')
# Agent attempted driving left through traffic and cause a minor accident. (rewarded -20.04)
# 44% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# Environment.step(): t = 14
# Environment.act() [POST]: location: (6, 5), heading: (0, -1), action: forward, reward: 0.636171571043
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'right', 'right': 'left', 'left': 'left'}, 'violation': 0, 'light': 'green', 'state': ('green', 'right', 'left', 'right'), 'deadline': 11, 't': 14, 'action': 'forward', 'reward': 0.6361715710430363, 'waypoint': 'right'}
# Agent previous state: ('green', 'right', 'left', 'right')
# Agent drove forward instead of right. (rewarded 0.64)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# Environment.step(): t = 15
# Environment.act() [POST]: location: (6, 5), heading: (0, -1), action: left, reward: -39.6418694643
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': 'forward', 'left': 'left'}, 'violation': 4, 'light': 'red', 'state': ('red', 'left', 'left', 'right'), 'deadline': 10, 't': 15, 'action': 'left', 'reward': -39.6418694642973, 'waypoint': 'right'}
# Agent previous state: ('red', 'left', 'left', 'right')
# Agent attempted driving left through a red light with traffic and cause a major accident. (rewarded -39.64)
# 36% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# Environment.step(): t = 16
# Environment.act() [POST]: location: (6, 5), heading: (0, -1), action: forward, reward: -10.3746871868
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'left', None, 'right'), 'deadline': 9, 't': 16, 'action': 'forward', 'reward': -10.37468718677687, 'waypoint': 'right'}
# Agent previous state: ('red', 'left', None, 'right')
# Agent attempted driving forward through a red light. (rewarded -10.37)
# 32% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# Environment.step(): t = 17
# Environment.act() [POST]: location: (5, 5), heading: (-1, 0), action: left, reward: 0.1228835538
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': None, 'left': 'forward'}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', 'forward', 'right'), 'deadline': 8, 't': 17, 'action': 'left', 'reward': 0.12288355380040294, 'waypoint': 'right'}
# Agent previous state: ('green', 'left', 'forward', 'right')
# Agent drove left instead of right. (rewarded 0.12)
# 28% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# Environment.step(): t = 18
# Environment.act() [POST]: location: (5, 4), heading: (0, -1), action: right, reward: 1.45460560462
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': 'left', 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'left'), 'deadline': 7, 't': 18, 'action': 'right', 'reward': 1.4546056046224292, 'waypoint': 'left'}
# Agent previous state: ('green', None, None, 'left')
# Agent drove right instead of left. (rewarded 1.45)
# 24% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# Environment.step(): t = 19
# Environment.act() [POST]: location: (6, 4), heading: (1, 0), action: right, reward: 1.11262702096
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'right'), 'deadline': 6, 't': 19, 'action': 'right', 'reward': 1.1126270209616993, 'waypoint': 'right'}
# Agent previous state: ('green', None, None, 'right')
# Agent followed the waypoint right. (rewarded 1.11)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 20 Results
# \-------------------
#
# Environment.step(): t = 20
# Environment.act() [POST]: location: (6, 5), heading: (0, 1), action: right, reward: 0.981445294852
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', None, 'forward'), 'deadline': 5, 't': 20, 'action': 'right', 'reward': 0.9814452948517636, 'waypoint': 'forward'}
# Agent previous state: ('green', 'left', None, 'forward')
# Agent drove right instead of forward. (rewarded 0.98)
# 16% of time remaining to reach destination.
#
# /-------------------
# | Step 21 Results
# \-------------------
#
# Environment.step(): t = 21
# Environment.act() [POST]: location: (6, 6), heading: (0, 1), action: forward, reward: -0.632744691678
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'forward', None, 'left'), 'deadline': 4, 't': 21, 'action': 'forward', 'reward': -0.6327446916778089, 'waypoint': 'left'}
# Agent previous state: ('green', 'forward', None, 'left')
# Agent drove forward instead of left. (rewarded -0.63)
# 12% of time remaining to reach destination.
#
# /-------------------
# | Step 22 Results
# \-------------------
#
# Environment.step(): t = 22
# Environment.act() [POST]: location: (6, 7), heading: (0, 1), action: forward, reward: 0.229241982465
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': 'right', 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', None, 'left'), 'deadline': 3, 't': 22, 'action': 'forward', 'reward': 0.22924198246473892, 'waypoint': 'left'}
# Agent previous state: ('green', 'left', None, 'left')
# Agent drove forward instead of left. (rewarded 0.23)
# 8% of time remaining to reach destination.
#
# /-------------------
# | Step 23 Results
# \-------------------
#
# Environment.step(): t = 23
# Environment.act() [POST]: location: (5, 7), heading: (-1, 0), action: right, reward: -0.567165524062
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'forward', None, 'left'), 'deadline': 2, 't': 23, 'action': 'right', 'reward': -0.5671655240620375, 'waypoint': 'left'}
# Agent previous state: ('red', 'forward', None, 'left')
# Agent drove right instead of left. (rewarded -0.57)
# 4% of time remaining to reach destination.
#
# /-------------------
# | Step 24 Results
# \-------------------
#
# Environment.step(): t = 24
# Environment.act() [POST]: location: (5, 7), heading: (-1, 0), action: None, reward: 0.999374477604
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': 'left', 'left': 'left'}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', 'left', 'left'), 'deadline': 1, 't': 24, 'action': None, 'reward': 0.9993744776037585, 'waypoint': 'left'}
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Agent previous state: ('green', 'left', 'left', 'left')
# Agent idled at a green light with oncoming traffic. (rewarded 1.00)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 3
# \-------------------------
#
# Environment.reset(): Trial set up with start = (3, 4), destination = (4, 7), deadline = 20
# Simulating trial. . .
# epsilon = 0.9703; alpha = 0.8000
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# Environment.step(): t = 0
# Environment.act() [POST]: location: (3, 5), heading: (0, 1), action: right, reward: 1.43578770622
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', None, None, 'forward'), 'deadline': 20, 't': 0, 'action': 'right', 'reward': 1.4357877062245819, 'waypoint': 'forward'}
# Agent previous state: ('red', None, None, 'forward')
# Agent drove right instead of forward. (rewarded 1.44)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# Environment.step(): t = 1
# Environment.act() [POST]: location: (4, 5), heading: (1, 0), action: left, reward: 2.81931797053
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': 'forward'}, 'violation': 0, 'light': 'green', 'state': ('green', None, 'forward', 'left'), 'deadline': 19, 't': 1, 'action': 'left', 'reward': 2.8193179705335405, 'waypoint': 'left'}
# Agent previous state: ('green', None, 'forward', 'left')
# Agent followed the waypoint left. (rewarded 2.82)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# Environment.step(): t = 2
# Environment.act() [POST]: location: (4, 5), heading: (1, 0), action: forward, reward: -9.73207377931
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': 'right'}, 'violation': 2, 'light': 'red', 'state': ('red', 'forward', 'right', 'right'), 'deadline': 18, 't': 2, 'action': 'forward', 'reward': -9.732073779314772, 'waypoint': 'right'}
# Agent previous state: ('red', 'forward', 'right', 'right')
# Agent attempted driving forward through a red light. (rewarded -9.73)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# Environment.step(): t = 3
# Environment.act() [POST]: location: (5, 5), heading: (1, 0), action: forward, reward: 1.75902942779
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'forward', None, 'right'), 'deadline': 17, 't': 3, 'action': 'forward', 'reward': 1.7590294277889793, 'waypoint': 'right'}
# Agent previous state: ('green', 'forward', None, 'right')
# Agent drove forward instead of right. (rewarded 1.76)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# Environment.step(): t = 4
# Environment.act() [POST]: location: (5, 6), heading: (0, 1), action: right, reward: 1.12505696657
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'right', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'right', None, 'right'), 'deadline': 16, 't': 4, 'action': 'right', 'reward': 1.1250569665669743, 'waypoint': 'right'}
# Agent previous state: ('red', 'right', None, 'right')
# Agent followed the waypoint right. (rewarded 1.13)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# Environment.step(): t = 5
# Environment.act() [POST]: location: (4, 6), heading: (-1, 0), action: right, reward: 1.55297742125
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'right'), 'deadline': 15, 't': 5, 'action': 'right', 'reward': 1.5529774212531244, 'waypoint': 'right'}
# Agent previous state: ('red', 'left', None, 'right')
# Agent followed the waypoint right. (rewarded 1.55)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# Environment.step(): t = 6
# Environment.act() [POST]: location: (4, 6), heading: (-1, 0), action: None, reward: 0.903217348262
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': 'left', 'left': 'left'}, 'violation': 0, 'light': 'red', 'state': ('red', None, 'left', 'left'), 'deadline': 14, 't': 6, 'action': None, 'reward': 0.9032173482616304, 'waypoint': 'left'}
# Agent previous state: ('red', None, 'left', 'left')
# Agent properly idled at a red light. (rewarded 0.90)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# Environment.step(): t = 7
# Environment.act() [POST]: location: (4, 6), heading: (-1, 0), action: None, reward: 2.615990484
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'right', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'right', None, 'left'), 'deadline': 13, 't': 7, 'action': None, 'reward': 2.6159904840049273, 'waypoint': 'left'}
# Agent previous state: ('red', 'right', None, 'left')
# Agent properly idled at a red light. (rewarded 2.62)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# Environment.step(): t = 8
# Environment.act() [POST]: location: (4, 6), heading: (-1, 0), action: None, reward: 2.75024201233
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'right', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'right', None, 'left'), 'deadline': 12, 't': 8, 'action': None, 'reward': 2.7502420123264297, 'waypoint': 'left'}
# Agent previous state: ('red', 'right', None, 'left')
# Agent properly idled at a red light. (rewarded 2.75)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# Environment.step(): t = 9
# Environment.act() [POST]: location: (4, 6), heading: (-1, 0), action: None, reward: 2.14120330217
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', None, None, 'left'), 'deadline': 11, 't': 9, 'action': None, 'reward': 2.1412033021749832, 'waypoint': 'left'}
# Agent previous state: ('red', None, None, 'left')
# Agent properly idled at a red light. (rewarded 2.14)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# Environment.step(): t = 10
# Environment.act() [POST]: location: (4, 6), heading: (-1, 0), action: None, reward: 2.67987081105
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', None, None, 'left'), 'deadline': 10, 't': 10, 'action': None, 'reward': 2.679870811046422, 'waypoint': 'left'}
# Agent previous state: ('red', None, None, 'left')
# Agent properly idled at a red light. (rewarded 2.68)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# Environment.step(): t = 11
# Environment.act(): Primary agent has reached destination!
# Environment.act() [POST]: location: (4, 7), heading: (0, 1), action: left, reward: 2.09748534954
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': 'left'}, 'violation': 0, 'light': 'green', 'state': ('green', None, 'left', 'left'), 'deadline': 9, 't': 11, 'action': 'left', 'reward': 2.0974853495387444, 'waypoint': 'left'}
# Agent previous state: ('green', None, 'left', 'left')
# Agent followed the waypoint left. (rewarded 2.10)
# 40% of time remaining to reach destination.
#
# Trial Completed!
# Agent reached the destination.
#
# /-------------------------
# | Training trial 4
# \-------------------------
#
# Environment.reset(): Trial set up with start = (6, 6), destination = (2, 2), deadline = 30
# Simulating trial. . .
# epsilon = 0.9606; alpha = 0.8000
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# Environment.step(): t = 0
# Environment.act() [POST]: location: (6, 6), heading: (-1, 0), action: None, reward: 1.07953775379
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', None, None, 'left'), 'deadline': 30, 't': 0, 'action': None, 'reward': 1.0795377537872597, 'waypoint': 'left'}
# Agent previous state: ('red', None, None, 'left')
# Agent properly idled at a red light. (rewarded 1.08)
# 97% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# Environment.step(): t = 1
# Environment.act() [POST]: location: (6, 6), heading: (-1, 0), action: None, reward: 2.96539181446
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'forward', None, 'left'), 'deadline': 29, 't': 1, 'action': None, 'reward': 2.965391814463946, 'waypoint': 'left'}
# Agent previous state: ('red', 'forward', None, 'left')
# Agent properly idled at a red light. (rewarded 2.97)
# 93% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# Environment.step(): t = 2
# Environment.act() [POST]: location: (6, 6), heading: (-1, 0), action: None, reward: 2.53175350681
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'forward', None, 'left'), 'deadline': 28, 't': 2, 'action': None, 'reward': 2.5317535068098156, 'waypoint': 'left'}
# Agent previous state: ('red', 'forward', None, 'left')
# Agent properly idled at a red light. (rewarded 2.53)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# Environment.step(): t = 3
# Environment.act() [POST]: location: (6, 6), heading: (-1, 0), action: None, reward: 1.26059740809
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'forward', None, 'left'), 'deadline': 27, 't': 3, 'action': None, 'reward': 1.2605974080898796, 'waypoint': 'left'}
# Agent previous state: ('red', 'forward', None, 'left')
# Agent properly idled at a red light. (rewarded 1.26)
# 87% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# Environment.step(): t = 4
# Environment.act() [POST]: location: (6, 5), heading: (0, -1), action: right, reward: 0.936284018544
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 26, 't': 4, 'action': 'right', 'reward': 0.9362840185437978, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent drove right instead of left. (rewarded 0.94)
# 83% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# Environment.step(): t = 5
# Environment.act() [POST]: location: (6, 5), heading: (0, -1), action: left, reward: -9.48254991182
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'left', None, 'right'), 'deadline': 25, 't': 5, 'action': 'left', 'reward': -9.482549911823584, 'waypoint': 'right'}
# Agent previous state: ('red', 'left', None, 'right')
# Agent attempted driving left through a red light. (rewarded -9.48)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# Environment.step(): t = 6
# Environment.act() [POST]: location: (7, 5), heading: (1, 0), action: right, reward: 2.12346699938
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'right'), 'deadline': 24, 't': 6, 'action': 'right', 'reward': 2.12346699938466, 'waypoint': 'right'}
# Agent previous state: ('red', 'left', None, 'right')
# Agent followed the waypoint right. (rewarded 2.12)
# 77% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# Environment.step(): t = 7
# Environment.act() [POST]: location: (7, 6), heading: (0, 1), action: right, reward: 0.653820273902
# ...
# Agent previous state: ('green', None, 'right', 'forward')
# Agent followed the waypoint forward. (rewarded 2.51)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# Environment.step(): t = 12
# Environment.act() [POST]: location: (3, 7), heading: (0, 1), action: None, reward: 1.28788841262
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'right', 'right': None, 'left': 'forward'}, 'violation': 0, 'light': 'red', 'state': ('red', 'right', 'forward', 'forward'), 'deadline': 8, 't': 12, 'action': None, 'reward': 1.2878884126169938, 'waypoint': 'forward'}
# Agent previous state: ('red', 'right', 'forward', 'forward')
# Agent properly idled at a red light. (rewarded 1.29)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# Environment.step(): t = 13
# Environment.act() [POST]: location: (2, 7), heading: (-1, 0), action: right, reward: -0.156817405809
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'forward', 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'forward', None, 'forward'), 'deadline': 7, 't': 13, 'action': 'right', 'reward': -0.15681740580879822, 'waypoint': 'forward'}
# Agent previous state: ('green', 'forward', None, 'forward')
# Agent drove right instead of forward. (rewarded -0.16)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# Environment.step(): t = 14
# Environment.act() [POST]: location: (2, 7), heading: (-1, 0), action: None, reward: 0.742761743099
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 6, 't': 14, 'action': None, 'reward': 0.7427617430989908, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent properly idled at a red light. (rewarded 0.74)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# Environment.step(): t = 15
# Environment.act() [POST]: location: (2, 7), heading: (-1, 0), action: None, reward: 1.9541393953
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': 'forward', 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 5, 't': 15, 'action': None, 'reward': 1.9541393952969588, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent properly idled at a red light. (rewarded 1.95)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# Environment.step(): t = 16
# Environment.act() [POST]: location: (2, 6), heading: (0, -1), action: right, reward: 0.42523164178
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', None, 'left'), 'deadline': 4, 't': 16, 'action': 'right', 'reward': 0.42523164178037587, 'waypoint': 'left'}
# Agent previous state: ('green', 'left', None, 'left')
# Agent drove right instead of left. (rewarded 0.43)
# 15% of time remaining to reach destination.
#
# /-------------------
# | Step 17 Results
# \-------------------
#
# Environment.step(): t = 17
# Environment.act() [POST]: location: (2, 5), heading: (0, -1), action: forward, reward: 0.675828431697
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', None, 'right'), 'deadline': 3, 't': 17, 'action': 'forward', 'reward': 0.6758284316970061, 'waypoint': 'right'}
# Agent previous state: ('green', 'left', None, 'right')
# Agent drove forward instead of right. (rewarded 0.68)
# 10% of time remaining to reach destination.
#
# /-------------------
# | Step 18 Results
# \-------------------
#
# Environment.step(): t = 18
# Environment.act() [POST]: location: (3, 5), heading: (1, 0), action: right, reward: 1.45438214922
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'right'), 'deadline': 2, 't': 18, 'action': 'right', 'reward': 1.454382149222149, 'waypoint': 'right'}
# Agent previous state: ('green', None, None, 'right')
# Agent followed the waypoint right. (rewarded 1.45)
# 5% of time remaining to reach destination.
#
# /-------------------
# | Step 19 Results
# \-------------------
#
# Environment.step(): t = 19
# Environment.act() [POST]: location: (3, 6), heading: (0, 1), action: right, reward: 1.74140428949
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'right'), 'deadline': 1, 't': 19, 'action': 'right', 'reward': 1.741404289488483, 'waypoint': 'right'}
# Environment.step(): Primary agent ran out of time! Trial aborted.
# Agent previous state: ('green', None, None, 'right')
# Agent followed the waypoint right. (rewarded 1.74)
# 0% of time remaining to reach destination.
#
# Trial Aborted!
# Agent did not reach the destination.
#
# /-------------------------
# | Training trial 70
# \-------------------------
#
# Environment.reset(): Trial set up with start = (5, 6), destination = (2, 5), deadline = 20
# Simulating trial. . .
# epsilon = 0.4948; alpha = 0.8000
#
# /-------------------
# | Step 0 Results
# \-------------------
#
# Environment.step(): t = 0
# Environment.act() [POST]: location: (5, 6), heading: (0, -1), action: None, reward: 2.62482881886
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 20, 't': 0, 'action': None, 'reward': 2.62482881885734, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent properly idled at a red light. (rewarded 2.62)
# 95% of time remaining to reach destination.
#
# /-------------------
# | Step 1 Results
# \-------------------
#
# Environment.step(): t = 1
# Environment.act() [POST]: location: (5, 6), heading: (0, -1), action: None, reward: 2.36871726178
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 19, 't': 1, 'action': None, 'reward': 2.36871726178235, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent properly idled at a red light. (rewarded 2.37)
# 90% of time remaining to reach destination.
#
# /-------------------
# | Step 2 Results
# \-------------------
#
# Environment.step(): t = 2
# Environment.act() [POST]: location: (5, 6), heading: (0, -1), action: None, reward: 0.9866326238
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': 'forward', 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 18, 't': 2, 'action': None, 'reward': 0.9866326238000453, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent properly idled at a red light. (rewarded 0.99)
# 85% of time remaining to reach destination.
#
# /-------------------
# | Step 3 Results
# \-------------------
#
# Environment.step(): t = 3
# Environment.act() [POST]: location: (5, 6), heading: (0, -1), action: None, reward: 2.66435098016
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 17, 't': 3, 'action': None, 'reward': 2.664350980163543, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent properly idled at a red light. (rewarded 2.66)
# 80% of time remaining to reach destination.
#
# /-------------------
# | Step 4 Results
# \-------------------
#
# Environment.step(): t = 4
# Environment.act() [POST]: location: (5, 6), heading: (0, -1), action: None, reward: 1.54482207138
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': 'left', 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 16, 't': 4, 'action': None, 'reward': 1.5448220713759222, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent properly idled at a red light. (rewarded 1.54)
# 75% of time remaining to reach destination.
#
# /-------------------
# | Step 5 Results
# \-------------------
#
# Environment.step(): t = 5
# Environment.act() [POST]: location: (5, 6), heading: (0, -1), action: left, reward: -10.7142311422
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 2, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 15, 't': 5, 'action': 'left', 'reward': -10.714231142236475, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent attempted driving left through a red light. (rewarded -10.71)
# 70% of time remaining to reach destination.
#
# /-------------------
# | Step 6 Results
# \-------------------
#
# Environment.step(): t = 6
# Environment.act() [POST]: location: (6, 6), heading: (1, 0), action: right, reward: 1.00785199779
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': 'forward', 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', None, 'left'), 'deadline': 14, 't': 6, 'action': 'right', 'reward': 1.0078519977891116, 'waypoint': 'left'}
# Agent previous state: ('green', 'left', None, 'left')
# Agent drove right instead of left. (rewarded 1.01)
# 65% of time remaining to reach destination.
#
# /-------------------
# | Step 7 Results
# \-------------------
#
# Environment.step(): t = 7
# Environment.act() [POST]: location: (7, 6), heading: (1, 0), action: forward, reward: 2.63948992499
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'forward'), 'deadline': 13, 't': 7, 'action': 'forward', 'reward': 2.639489924987058, 'waypoint': 'forward'}
# Agent previous state: ('green', None, None, 'forward')
# Agent followed the waypoint forward. (rewarded 2.64)
# 60% of time remaining to reach destination.
#
# /-------------------
# | Step 8 Results
# \-------------------
#
# Environment.step(): t = 8
# Environment.act() [POST]: location: (8, 6), heading: (1, 0), action: forward, reward: 2.50392299698
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': None, 'right': 'forward', 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', None, None, 'forward'), 'deadline': 12, 't': 8, 'action': 'forward', 'reward': 2.503922996980586, 'waypoint': 'forward'}
# Agent previous state: ('green', None, None, 'forward')
# Agent followed the waypoint forward. (rewarded 2.50)
# 55% of time remaining to reach destination.
#
# /-------------------
# | Step 9 Results
# \-------------------
#
# Environment.step(): t = 9
# Environment.act() [POST]: location: (8, 6), heading: (1, 0), action: None, reward: 2.09700708862
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': 'left'}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', 'left', 'forward'), 'deadline': 11, 't': 9, 'action': None, 'reward': 2.097007088620941, 'waypoint': 'forward'}
# Agent previous state: ('red', 'left', 'left', 'forward')
# Agent properly idled at a red light. (rewarded 2.10)
# 50% of time remaining to reach destination.
#
# /-------------------
# | Step 10 Results
# \-------------------
#
# Environment.step(): t = 10
# Environment.act() [POST]: location: (1, 6), heading: (1, 0), action: forward, reward: 1.90821276268
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': 'right', 'left': 'left'}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', 'left', 'forward'), 'deadline': 10, 't': 10, 'action': 'forward', 'reward': 1.908212762677611, 'waypoint': 'forward'}
# Agent previous state: ('green', 'left', 'left', 'forward')
# Agent followed the waypoint forward. (rewarded 1.91)
# 45% of time remaining to reach destination.
#
# /-------------------
# | Step 11 Results
# \-------------------
#
# Environment.step(): t = 11
# Environment.act() [POST]: location: (1, 7), heading: (0, 1), action: right, reward: 0.24659567487
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'right', 'right': None, 'left': 'left'}, 'violation': 0, 'light': 'red', 'state': ('red', 'right', 'left', 'forward'), 'deadline': 9, 't': 11, 'action': 'right', 'reward': 0.24659567486992495, 'waypoint': 'forward'}
# Agent previous state: ('red', 'right', 'left', 'forward')
# Agent drove right instead of forward. (rewarded 0.25)
# 40% of time remaining to reach destination.
#
# /-------------------
# | Step 12 Results
# \-------------------
#
# Environment.step(): t = 12
# Environment.act() [POST]: location: (1, 7), heading: (0, 1), action: None, reward: 0.986746048056
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'right', 'right': 'right', 'left': 'left'}, 'violation': 0, 'light': 'red', 'state': ('red', 'right', 'left', 'left'), 'deadline': 8, 't': 12, 'action': None, 'reward': 0.9867460480564587, 'waypoint': 'left'}
# Agent previous state: ('red', 'right', 'left', 'left')
# Agent properly idled at a red light. (rewarded 0.99)
# 35% of time remaining to reach destination.
#
# /-------------------
# | Step 13 Results
# \-------------------
#
# Environment.step(): t = 13
# Environment.act() [POST]: location: (1, 7), heading: (0, 1), action: None, reward: 0.959624265695
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': None, 'right': None, 'left': 'right'}, 'violation': 0, 'light': 'red', 'state': ('red', None, 'right', 'left'), 'deadline': 7, 't': 13, 'action': None, 'reward': 0.9596242656953435, 'waypoint': 'left'}
# Agent previous state: ('red', None, 'right', 'left')
# Agent properly idled at a red light. (rewarded 0.96)
# 30% of time remaining to reach destination.
#
# /-------------------
# | Step 14 Results
# \-------------------
#
# Environment.step(): t = 14
# Environment.act() [POST]: location: (1, 7), heading: (0, 1), action: None, reward: 1.11188098558
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 6, 't': 14, 'action': None, 'reward': 1.1118809855768228, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent properly idled at a red light. (rewarded 1.11)
# 25% of time remaining to reach destination.
#
# /-------------------
# | Step 15 Results
# \-------------------
#
# Environment.step(): t = 15
# Environment.act() [POST]: location: (1, 7), heading: (0, 1), action: None, reward: 0.952852604433
# Environment.act(): Step data: {'inputs': {'light': 'red', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'red', 'state': ('red', 'left', None, 'left'), 'deadline': 5, 't': 15, 'action': None, 'reward': 0.952852604433214, 'waypoint': 'left'}
# Agent previous state: ('red', 'left', None, 'left')
# Agent properly idled at a red light. (rewarded 0.95)
# 20% of time remaining to reach destination.
#
# /-------------------
# | Step 16 Results
# \-------------------
#
# Environment.step(): t = 16
# Environment.act() [POST]: location: (8, 7), heading: (-1, 0), action: right, reward: 0.885825880752
# Environment.act(): Step data: {'inputs': {'light': 'green', 'oncoming': 'left', 'right': None, 'left': None}, 'violation': 0, 'light': 'green', 'state': ('green', 'left', None, 'left'), 'deadline': 4, 't': 16, 'action': 'right', 'reward': 0.8858258807523347, 'waypoint': 'left'}
# Agent previous state: ('green', 'left', None, 'left')
# Agent drove right instead of left. (rewarded 0.89)
# 15% of time remaining to reach destination.
